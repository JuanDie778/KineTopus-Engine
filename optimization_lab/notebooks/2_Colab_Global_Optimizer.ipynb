# %% [markdown]
# # Global Optimizer Lab (Colab Ready)
# Este notebook está diseñado para ejecutarse en entornos de alto rendimiento. Orquesta el `optimizer_pipeline.py` para descubrir la ecuación TDA de referencia y buscar la calibración óptima.

# %%
# !pip install -r ../colab_requirements.txt

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from optimizer_pipeline import GlobalOptimizer

optimizer = GlobalOptimizer()
optimizer.run_optimization_loop()
