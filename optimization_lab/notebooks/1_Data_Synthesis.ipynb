# %% [markdown]
# # Data Synthesis Lab
# Generación de entornos sintéticos (cajas de arena) para probar el motor de optimización.

# %%
import numpy as np
import pandas as pd
import sys
import os

# Añadir la raíz del optimization_lab al path
sys.path.append(os.path.abspath('..'))

from core.ui.market_loader import MarketLoader
